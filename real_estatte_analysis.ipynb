# %% [markdown]
# #Real Estate Data Analytics Project
# #Project ini bertujuan untuk menganalisis:
# #- tren harga properti
# #- tipe properti
# #- distribusi harga
# #- hubungan antara assessed value dan sale amount
#
# #Dataset yang digunakan:
# #Real Estate Sales Datase periode 2001-2022

# %% [markdown]
# # 🏠 Real Estate Data Analytics Project
#
# # Project ini bertujuan untuk menganalisis:
#
# # - tren harga properti
# # - tipe properti
# # - distribusi harga
# # - hubungan antara assessed value dan sale amount
#
# ## Dataset yang digunakan
#
# # Real Estate Sales Dataset periode 2001-2022.

# %%
print("Hi Data Analytics")
# Out:
# Hi Data Analytics

# %% [markdown]
# # import library untuk :
# ## membaca dataset
# ## mengolah data dan lanjut ke visualisasi dan analisa nya

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Dataset real estate dengam menggunakan pandas data frame

# %%
df = pd.read_csv("Real_Estate_Sales_2001-2022_GL.csv")
# Out:
# C:\Users\SWIDJAJA\AppData\Local\Temp\ipykernel_11688\708756159.py:1: DtypeWarning: Columns (0: Property Type, 1: Residential Type, 2: Non Use Code, 3: Assessor Remarks, 4: OPM remarks) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Real_Estate_Sales_2001-2022_GL.csv")

# %% [markdown]
# ## EDA yaitu Exploratory Data Analysis untuk pahami struktur dari 5 data pertama dari dataset nya.

# %%
df.head ()
# Out:
#    Unnamed: 0  Serial Number  List Year Date Recorded     Town  \
# 0           0        2020177       2020    04/14/2021  Ansonia
# 1           1        2020225       2020    05/26/2021  Ansonia
# 2           2        2020348       2020    09/13/2021  Ansonia
# 3           3        2020090       2020    12/14/2020  Ansonia
# 4           4         210288       2021    06/20/2022     Avon
#
#            Address  Assessed Value  Sale Amount  Sales Ratio Property Type  \
# 0    323 BEAVER ST        133000.0     248400.0       0.5354   Residential
# 1   152 JACKSON ST        110500.0     239900.0       0.4606   Residential
# 2  230 WAKELEE AVE        150500.0     325000.0       0.4630    Commercial
# 3      57 PLATT ST        127400.0     202500.0       0.6291   Residential
# 4   12 BYRON DRIVE        179990.0     362500.0       0.4965   Residential
#
#   Residential Type Non Use Code Assessor Remarks OPM remarks  \
# 0    Single Family          NaN              NaN         NaN
# ...

# %% [markdown]
# ## Data set shape untuk melihat total baris dan kolom

# %%
df.shape
# Out:
# (1097629, 15)

# %% [markdown]
# ## Dataset imformation = melihat non null atas tiap data dan jumlah data pada setiap kolom

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1097629 entries, 0 to 1097628
# Data columns (total 15 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1097629 non-null  int64
#  1   Serial Number     1097629 non-null  int64
#  2   List Year         1097629 non-null  int64
#  3   Date Recorded     1097627 non-null  str
#  4   Town              1097629 non-null  str
#  5   Address           1097578 non-null  str
#  6   Assessed Value    1097629 non-null  float64
#  7   Sale Amount       1097629 non-null  float64
#  8   Sales Ratio       1097629 non-null  float64
#  9   Property Type     715183 non-null   str
#  10  Residential Type  699240 non-null   str
#  11  Non Use Code      313451 non-null   object
#  12  Assessor Remarks  171228 non-null   str
#  13  OPM remarks       13031 non-null    str
#  14  Location          298111 non-null   str
# dtypes: float64(3), int64(3), object(1), str(8)
# ...

# %% [markdown]
# ## Melihat type data angka bulat dan desimal juga text untuk alamat nya.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1097629 entries, 0 to 1097628
# Data columns (total 15 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1097629 non-null  int64
#  1   Serial Number     1097629 non-null  int64
#  2   List Year         1097629 non-null  int64
#  3   Date Recorded     1097627 non-null  str
#  4   Town              1097629 non-null  str
#  5   Address           1097578 non-null  str
#  6   Assessed Value    1097629 non-null  float64
#  7   Sale Amount       1097629 non-null  float64
#  8   Sales Ratio       1097629 non-null  float64
#  9   Property Type     715183 non-null   str
#  10  Residential Type  699240 non-null   str
#  11  Non Use Code      313451 non-null   object
#  12  Assessor Remarks  171228 non-null   str
#  13  OPM remarks       13031 non-null    str
#  14  Location          298111 non-null   str
# dtypes: float64(3), int64(3), object(1), str(8)
# ...

# %% [markdown]
# ## Cleaning : cek missing, hapus kolom yang tidak penting, lihat ada kah duplikasi dan lanjut ke filtering data dan check .
#
# ### Missing value analysis

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Serial Number             0
# List Year                 0
# Date Recorded             2
# Town                      0
# Address                  51
# Assessed Value            0
# Sale Amount               0
# Sales Ratio               0
# Property Type        382446
# Residential Type     398389
# Non Use Code         784178
# Assessor Remarks     926401
# OPM remarks         1084598
# Location             799518
# dtype: int64

# %% [markdown]
# ### Hapus kolom yang tidak diperlukan karena missing values nya banyak (Drop un-necassart coloums)

# %% [markdown]
# ### Kalau kolom tidak ada, = jangan error.

# %%
df = df.drop(
    columns=[
        "Unnamed: 0",
        "OPM remarks",
        "Assessor Remarks"
    ],
    errors="ignore"
)

# %%
df.head()
# Out:
#    Serial Number  List Year Date Recorded     Town          Address  \
# 0        2020177       2020    04/14/2021  Ansonia    323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia   152 JACKSON ST
# 2        2020348       2020    09/13/2021  Ansonia  230 WAKELEE AVE
# 3        2020090       2020    12/14/2020  Ansonia      57 PLATT ST
# 4         210288       2021    06/20/2022     Avon   12 BYRON DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 2        150500.0     325000.0       0.4630    Commercial              NaN
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 4        179990.0     362500.0       0.4965   Residential            Condo
#
#   Non Use Code                            Location
# 0          NaN          POINT (-73.06822 41.35014)
# ...

# %% [markdown]
# df.head()

# %% [markdown]
# ### Check untuk ada duplikasi di baris nya , menghindari rata-rata harga real estate dan jumlah transaksi bisa mendukung chart nantinya

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Filtering fungsi nya pemilihan data atas kondisi berdasarkan tujuan nya

# %%
df.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Non Use Code', 'Location'],
#       dtype='str')

# %% [markdown]
# # Filter data tujuan nya
# ##  Analisis trend , type, area  properti dengan periode tertentu.
# ### Pada tahap ini, analisis dilakukan untuk melihat bagaimana perubahan median harga properti dan seterusnya
# ### Insight ini penting bagi investor untuk memahami apakah pasar properti sedang mengalami naik / turun.

# %%
yearly_median = df.groupby("List Year")["Sale Amount"].median().reset_index()

# %%
yearly_median.head()
# Out:
#    List Year  Sale Amount
# 0       2001     165000.0
# 1       2002     185000.0
# 2       2003     205000.0
# 3       2004     235000.0
# 4       2005     247000.0

# %% [markdown]
# ### multi year filtering untuk mengetahui trend dari periode tertentu terlihat jelas seperti sekarang, sesudah vs sebelum covid
# ### type property serta lokasi dan range harga dari real eastate
# ### mencari extreme data

# %%
df_recent = df[df["List Year"] >= 2020]

# %%
df_recent.head()
# Out:
#    Serial Number  List Year Date Recorded     Town          Address  \
# 0        2020177       2020    04/14/2021  Ansonia    323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia   152 JACKSON ST
# 2        2020348       2020    09/13/2021  Ansonia  230 WAKELEE AVE
# 3        2020090       2020    12/14/2020  Ansonia      57 PLATT ST
# 4         210288       2021    06/20/2022     Avon   12 BYRON DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 2        150500.0     325000.0       0.4630    Commercial              NaN
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 4        179990.0     362500.0       0.4965   Residential            Condo
#
#   Non Use Code                            Location
# 0          NaN          POINT (-73.06822 41.35014)
# ...

# %%
df_recent = df[df["List Year"] <= 2020]

# %%
df_recent.head()
# Out:
#    Serial Number  List Year Date Recorded     Town          Address  \
# 0        2020177       2020    04/14/2021  Ansonia    323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia   152 JACKSON ST
# 2        2020348       2020    09/13/2021  Ansonia  230 WAKELEE AVE
# 3        2020090       2020    12/14/2020  Ansonia      57 PLATT ST
# 5         200500       2020    09/07/2021     Avon     245 NEW ROAD
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 2        150500.0     325000.0       0.4630    Commercial              NaN
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 5        217640.0     400000.0       0.5441   Residential    Single Family
#
#   Non Use Code                    Location
# 0          NaN  POINT (-73.06822 41.35014)
# ...

# %% [markdown]
# ### untuk residential

# %%
df_residential = df[df["Property Type"] == "Residential"]

# %%
df_residential.head()
# Out:
#    Serial Number  List Year Date Recorded     Town         Address  \
# 0        2020177       2020    04/14/2021  Ansonia   323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia  152 JACKSON ST
# 3        2020090       2020    12/14/2020  Ansonia     57 PLATT ST
# 4         210288       2021    06/20/2022     Avon  12 BYRON DRIVE
# 5         200500       2020    09/07/2021     Avon    245 NEW ROAD
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 4        179990.0     362500.0       0.4965   Residential            Condo
# 5        217640.0     400000.0       0.5441   Residential    Single Family
#
#   Non Use Code                            Location
# 0          NaN          POINT (-73.06822 41.35014)
# ...

# %%
df_town = df[df["Town"] == "Greenwich"]

# %%
df_town.head()
# Out:
#      Serial Number  List Year Date Recorded       Town              Address  \
# 107         200630       2020    02/16/2021  Greenwich              2350000
# 108         200693       2020    03/05/2021  Greenwich      10 NIMITZ PLACE
# 109         200890       2020    04/22/2021  Greenwich     188 BIBLE STREET
# 112         201711       2020    09/09/2021  Greenwich  15 SHOAL POINT ROAD
# 113         200386       2020    12/18/2020  Greenwich      328 LAKE AVENUE
#
#      Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 107       1964480.0    2350000.0       0.8359   Residential    Single Family
# 108        548800.0     870000.0       0.6308   Residential    Single Family
# 109        737590.0    1364000.0       0.5407   Residential    Single Family
# 112       2623950.0    3900000.0       0.6728   Residential    Single Family
# 113       1908690.0    2850000.0       0.6697   Residential    Single Family
#
#     Non Use Code                    Location
# ...

# %% [markdown]
# ### harga rumah yang akan melebihi dari 5% akan terhapus
# #### batas atas cap, dengan nilai jual nya yg extreme akan tidak diambil karena dikategorikan data extreme.

# %%
cap = df["Sale Amount"].quantile(0.95)

df_clean = df[df["Sale Amount"] <= cap]

# %%
df_clean.head()
# Out:
#    Serial Number  List Year Date Recorded     Town          Address  \
# 0        2020177       2020    04/14/2021  Ansonia    323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia   152 JACKSON ST
# 2        2020348       2020    09/13/2021  Ansonia  230 WAKELEE AVE
# 3        2020090       2020    12/14/2020  Ansonia      57 PLATT ST
# 4         210288       2021    06/20/2022     Avon   12 BYRON DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 2        150500.0     325000.0       0.4630    Commercial              NaN
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 4        179990.0     362500.0       0.4965   Residential            Condo
#
#   Non Use Code                            Location
# 0          NaN          POINT (-73.06822 41.35014)
# ...

# %%
df_valid = df[df["Sales Ratio"] > 0]

# %%
df_valid.head()
# Out:
#    Serial Number  List Year Date Recorded     Town          Address  \
# 0        2020177       2020    04/14/2021  Ansonia    323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia   152 JACKSON ST
# 2        2020348       2020    09/13/2021  Ansonia  230 WAKELEE AVE
# 3        2020090       2020    12/14/2020  Ansonia      57 PLATT ST
# 4         210288       2021    06/20/2022     Avon   12 BYRON DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 2        150500.0     325000.0       0.4630    Commercial              NaN
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 4        179990.0     362500.0       0.4965   Residential            Condo
#
#   Non Use Code                            Location
# 0          NaN          POINT (-73.06822 41.35014)
# ...

# %% [markdown]
# #### group berdasarkan tahun, bulan dengan kota dan type real estate

# %%
df.groupby("List Year")["Sale Amount"].median()
# Out:
# List Year
# 2001    165000.0
# 2002    185000.0
# 2003    205000.0
# 2004    235000.0
# 2005    247000.0
# 2006    265000.0
# 2007    245000.0
# 2008    215000.0
# 2009    217500.0
# 2010    210000.0
# 2011    213275.0
# 2012    220000.0
# 2013    206000.0
# 2014    214900.0
# 2015    210000.0
# 2016    225000.0
# 2017    225000.0
# 2018    225000.0
# 2019    253000.0
# 2020    285000.0
# 2021    310000.0
# 2022    322000.0
# Name: Sale Amount, dtype: float64

# %% [markdown]
# ### Table bulan dan tahun

# %%
df["Year"] = df["Date Recorded"].dt.year

# %%
df["Month"] = df["Date Recorded"].dt.month

# %%
df.groupby(["Year", "Month"])["Sale Amount"].median()
# Out:
# Year    Month
# 1999.0  4.0       95000.0
# 2001.0  8.0      596500.0
#         9.0      256000.0
#         10.0     150000.0
#         11.0     155000.0
#                    ...
# 2023.0  5.0      325000.0
#         6.0      350000.0
#         7.0      361500.0
#         8.0      351000.0
#         9.0      335000.0
# Name: Sale Amount, Length: 267, dtype: float64

# %%
df["Date Recorded"] = pd.to_datetime(df["Date Recorded"])
df.head()
# Out:
#    Serial Number  List Year Date Recorded     Town          Address  \
# 0        2020177       2020    2021-04-14  Ansonia    323 BEAVER ST
# 1        2020225       2020    2021-05-26  Ansonia   152 JACKSON ST
# 2        2020348       2020    2021-09-13  Ansonia  230 WAKELEE AVE
# 3        2020090       2020    2020-12-14  Ansonia      57 PLATT ST
# 4         210288       2021    2022-06-20     Avon   12 BYRON DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 2        150500.0     325000.0       0.4630    Commercial              NaN
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 4        179990.0     362500.0       0.4965   Residential            Condo
#
#   Non Use Code                            Location    Year  Month
# ...

# %%
df.columns
# Out:
# Index(['Serial Number', 'List Year', 'Date Recorded', 'Town', 'Address',
#        'Assessed Value', 'Sale Amount', 'Sales Ratio', 'Property Type',
#        'Residential Type', 'Non Use Code', 'Location', 'Year', 'Month'],
#       dtype='str')

# %%
df.groupby("List Year")["Sale Amount"].median()
# Out:
# List Year
# 2001    165000.0
# 2002    185000.0
# 2003    205000.0
# 2004    235000.0
# 2005    247000.0
# 2006    265000.0
# 2007    245000.0
# 2008    215000.0
# 2009    217500.0
# 2010    210000.0
# 2011    213275.0
# 2012    220000.0
# 2013    206000.0
# 2014    214900.0
# 2015    210000.0
# 2016    225000.0
# 2017    225000.0
# 2018    225000.0
# 2019    253000.0
# 2020    285000.0
# 2021    310000.0
# 2022    322000.0
# Name: Sale Amount, dtype: float64

# %%
df.groupby(["Year", "Month"])["Sale Amount"].median()
# Out:
# Year    Month
# 1999.0  4.0       95000.0
# 2001.0  8.0      596500.0
#         9.0      256000.0
#         10.0     150000.0
#         11.0     155000.0
#                    ...
# 2023.0  5.0      325000.0
#         6.0      350000.0
#         7.0      361500.0
#         8.0      351000.0
#         9.0      335000.0
# Name: Sale Amount, Length: 267, dtype: float64

# %%
df.groupby("Town")["Sale Amount"].median()
# Out:
# Town
# ***Unknown***    282450.0
# Andover          218500.0
# Ansonia          200000.0
# Ashford          167000.0
# Avon             358305.0
#                    ...
# Windsor Locks    176500.0
# Wolcott          211000.0
# Woodbridge       400000.0
# Woodbury         270975.0
# Woodstock        197500.0
# Name: Sale Amount, Length: 170, dtype: float64

# %%
df.groupby("Property Type")["Sale Amount"].median()
# Out:
# Property Type
# Apartments        500000.0
# Commercial        400000.0
# Condo             175000.0
# Four Family       189450.0
# Industrial        740000.0
# Public Utility     44500.0
# Residential       309900.0
# Single Family     250000.0
# Three Family      153000.0
# Two Family        162000.0
# Vacant Land       100000.0
# Name: Sale Amount, dtype: float64

# %%
df.groupby("Residential Type")["Sale Amount"].median()
# Out:
# Residential Type
# Condo            183500.0
# Four Family      228700.0
# Single Family    270000.0
# Three Family     185000.0
# Two Family       185000.0
# Name: Sale Amount, dtype: float64

# %%
### Filter trend dari kategori real estate

# %%
df.groupby(["List Year", "Property Type"])["Sale Amount"].median()
# Out:
# List Year  Property Type
# 2006       Condo             197500.0
#            Four Family       276750.0
#            Single Family     303000.0
#            Three Family      240000.0
#            Two Family        235000.0
#                                ...
# 2022       Commercial        380000.0
#            Industrial        700000.0
#            Public Utility    105000.0
#            Residential       325000.0
#            Vacant Land        95000.0
# Name: Sale Amount, Length: 88, dtype: float64

# %%
### filter untuk melihar volume dari market

# %%
df.groupby("Town").size()
# Out:
# Town
# ***Unknown***       1
# Andover           932
# Ansonia          5017
# Ashford          1467
# Avon             7866
#                  ...
# Windsor Locks    4700
# Wolcott          5241
# Woodbridge       2788
# Woodbury         3780
# Woodstock        3345
# Length: 170, dtype: int64

# %%
### Efesiensi dari penjualan per kota(town)

# %%
df.groupby("Town")["Sales Ratio"].mean()
# Out:
# Town
# ***Unknown***    0.235582
# Andover          0.778054
# Ansonia          0.908401
# Ashford          0.902646
# Avon             1.002314
#                    ...
# Windsor Locks    0.717097
# Wolcott          0.842909
# Woodbridge       1.013101
# Woodbury         0.869538
# Woodstock        1.184995
# Name: Sales Ratio, Length: 170, dtype: float64

# %% [markdown]
# ### filter untuk mengetahui pertumbuhan dari perubahan % dari baris sebelumnya berdasarkan tahun

# %%
yearly_table = pd.DataFrame({
    "Median Price": yearly,
    "Growth %": growth
})

print(yearly_table)
# Out:
#         Median Price   Growth %
# Year
# 1999.0       95000.0        NaN
# 2001.0      154900.0  63.052632
# 2002.0      170000.0   9.748225
# 2003.0      189900.0  11.705882
# 2004.0      214250.0  12.822538
# 2005.0      240000.0  12.018670
# 2006.0      250000.0   4.166667
# 2007.0      265000.0   6.000000
# 2008.0      238000.0 -10.188679
# 2009.0      212000.0 -10.924370
# 2010.0      219000.0   3.301887
# 2011.0      206041.0  -5.917352
# 2012.0      215000.0   4.348164
# 2013.0      218000.0   1.395349
# 2014.0      207500.0  -4.816514
# 2015.0      211000.0   1.686747
# 2016.0      214500.0   1.658768
# 2017.0      225000.0   4.895105
# 2018.0      225000.0   0.000000
# 2019.0      229000.0   1.777778
# 2020.0      265000.0  15.720524
# 2021.0      291000.0   9.811321
# 2022.0      315000.0   8.247423
# 2023.0      326500.0   3.650794

# %% [markdown]
# ### Ringkasan dari informasi di baris-baris sebelumnya di atas (row 103) ada data yang extreme sehingga dilakuakn recheck dengan df.describe nya

# %%
df.describe()
# Out:
#        Serial Number     List Year               Date Recorded  \
# count   1.097629e+06  1.097629e+06                     1097627
# mean    5.370357e+05  2.011218e+03  2012-06-28 08:23:23.755556
# min     0.000000e+00  2.001000e+03         1999-04-05 00:00:00
# 25%     3.071300e+04  2.005000e+03         2005-11-04 00:00:00
# 50%     8.070600e+04  2.011000e+03         2012-08-13 00:00:00
# 75%     1.703410e+05  2.018000e+03         2018-10-16 00:00:00
# max     2.000500e+09  2.022000e+03         2023-09-29 00:00:00
# std     7.526074e+06  6.773485e+00                         NaN
#
#        Assessed Value   Sale Amount   Sales Ratio          Year         Month
# count    1.097629e+06  1.097629e+06  1.097629e+06  1.097627e+06  1.097627e+06
# mean     2.818016e+05  4.053146e+05  9.603926e+00  2.011967e+03  6.817979e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00  1.999000e+03  1.000000e+00
# 25%      8.909000e+04  1.450000e+05  4.778667e-01  2.005000e+03  4.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1097629 entries, 0 to 1097628
# Data columns (total 14 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Serial Number     1097629 non-null  int64
#  1   List Year         1097629 non-null  int64
#  2   Date Recorded     1097627 non-null  datetime64[us]
#  3   Town              1097629 non-null  str
#  4   Address           1097578 non-null  str
#  5   Assessed Value    1097629 non-null  float64
#  6   Sale Amount       1097629 non-null  float64
#  7   Sales Ratio       1097629 non-null  float64
#  8   Property Type     715183 non-null   str
#  9   Residential Type  699240 non-null   str
#  10  Non Use Code      313451 non-null   object
#  11  Location          298111 non-null   str
#  12  Year              1097627 non-null  float64
#  13  Month             1097627 non-null  float64
# dtypes: datetime64[us](1), float64(5), int64(2), object(1), str(5)
# memory usage: 117.2+ MB

# %% [markdown]
# ### Type property yang kosong di exclude

# %%
property_df = df_clean.dropna(subset=["Property Type"])

df = df.dropna(subset=["Property Type"])

# %%
property_df.head()
# Out:
#    Serial Number  List Year Date Recorded     Town          Address  \
# 0        2020177       2020    04/14/2021  Ansonia    323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia   152 JACKSON ST
# 2        2020348       2020    09/13/2021  Ansonia  230 WAKELEE AVE
# 3        2020090       2020    12/14/2020  Ansonia      57 PLATT ST
# 4         210288       2021    06/20/2022     Avon   12 BYRON DRIVE
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 2        150500.0     325000.0       0.4630    Commercial              NaN
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 4        179990.0     362500.0       0.4965   Residential            Condo
#
#   Non Use Code                            Location
# 0          NaN          POINT (-73.06822 41.35014)
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 715183 entries, 0 to 1097628
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     715183 non-null  int64
#  1   List Year         715183 non-null  int64
#  2   Date Recorded     715183 non-null  datetime64[us]
#  3   Town              715183 non-null  str
#  4   Address           715179 non-null  str
#  5   Assessed Value    715183 non-null  float64
#  6   Sale Amount       715183 non-null  float64
#  7   Sales Ratio       715183 non-null  float64
#  8   Property Type     715183 non-null  str
#  9   Residential Type  699240 non-null  str
#  10  Non Use Code      208968 non-null  object
#  11  Location          226458 non-null  str
#  12  Year              715183 non-null  float64
#  13  Month             715183 non-null  float64
# dtypes: datetime64[us](1), float64(5), int64(2), object(1), str(5)
# memory usage: 81.8+ MB

# %% [markdown]
# ### Type residential yang kosong di exclude

# %%
property_df = df_clean.dropna(subset=["Residential Type"])

df = df.dropna(subset= ["Residential Type"])

# %%
property_df.head()
# Out:
#    Serial Number  List Year Date Recorded     Town         Address  \
# 0        2020177       2020    04/14/2021  Ansonia   323 BEAVER ST
# 1        2020225       2020    05/26/2021  Ansonia  152 JACKSON ST
# 3        2020090       2020    12/14/2020  Ansonia     57 PLATT ST
# 4         210288       2021    06/20/2022     Avon  12 BYRON DRIVE
# 5         200500       2020    09/07/2021     Avon    245 NEW ROAD
#
#    Assessed Value  Sale Amount  Sales Ratio Property Type Residential Type  \
# 0        133000.0     248400.0       0.5354   Residential    Single Family
# 1        110500.0     239900.0       0.4606   Residential     Three Family
# 3        127400.0     202500.0       0.6291   Residential       Two Family
# 4        179990.0     362500.0       0.4965   Residential            Condo
# 5        217640.0     400000.0       0.5441   Residential    Single Family
#
#   Non Use Code                            Location
# 0          NaN          POINT (-73.06822 41.35014)
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 699240 entries, 0 to 1097628
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Serial Number     699240 non-null  int64
#  1   List Year         699240 non-null  int64
#  2   Date Recorded     699240 non-null  datetime64[us]
#  3   Town              699240 non-null  str
#  4   Address           699236 non-null  str
#  5   Assessed Value    699240 non-null  float64
#  6   Sale Amount       699240 non-null  float64
#  7   Sales Ratio       699240 non-null  float64
#  8   Property Type     699240 non-null  str
#  9   Residential Type  699240 non-null  str
#  10  Non Use Code      201279 non-null  object
#  11  Location          214091 non-null  str
#  12  Year              699240 non-null  float64
#  13  Month             699240 non-null  float64
# dtypes: datetime64[us](1), float64(5), int64(2), object(1), str(5)
# memory usage: 80.0+ MB

# %% [markdown]
# ### Memeriksa kolom ulang

# %%
df.isnull().sum()
# Out:
# Serial Number            0
# List Year                0
# Date Recorded            0
# Town                     0
# Address                  4
# Assessed Value           0
# Sale Amount              0
# Sales Ratio              0
# Property Type            0
# Residential Type         0
# Non Use Code        497961
# Location            485149
# Year                     0
# Month                    0
# dtype: int64

# %% [markdown]
# ## Ringkasan Statistik

# %%
df.describe()
# Out:
#        Serial Number      List Year               Date Recorded  \
# count   6.992400e+05  699240.000000                      699240
# mean    7.484256e+05    2014.717728  2015-12-28 07:45:11.584005
# min     2.100000e+01    2006.000000         1999-04-05 00:00:00
# 25%     7.093175e+04    2011.000000         2011-10-05 00:00:00
# 50%     1.404660e+05    2015.000000         2016-07-19 00:00:00
# 75%     1.904870e+05    2019.000000         2020-05-29 00:00:00
# max     2.000500e+09    2022.000000         2023-09-29 00:00:00
# std     8.959386e+06       4.906458                         NaN
#
#        Assessed Value   Sale Amount   Sales Ratio           Year  \
# count    6.992400e+05  6.992400e+05  6.992400e+05  699240.000000
# mean     2.523573e+05  3.757951e+05  5.010083e+00    2015.461501
# min      0.000000e+00  0.000000e+00  0.000000e+00    1999.000000
# 25%      1.106000e+05  1.570000e+05  5.536000e-01    2011.000000
# ...

# %% [markdown]
# ### Dataframe baru setelah bersih

# %%
df_clean = df.copy()

# %%
df_clean.to_csv(
    "real_estate_clean.csv",
    index=False
)
